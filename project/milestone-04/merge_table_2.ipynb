# %%
# Import the tables of the data set as dataframes.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings


warnings.filterwarnings('ignore')
sns.set(font_scale=1.2)
sns.set_theme(style="whitegrid")

DATA_DIR = '../data' #You many change the directory

# %%
users = pd.read_csv('{}/users.csv'.format(DATA_DIR))
events = pd.read_csv('{}/events.csv'.format(DATA_DIR))
transactions = pd.read_csv('{}/transactions.csv'.format(DATA_DIR))
sessions = pd.read_csv('{}/learn_sessions_transactions.csv.gz'.format(DATA_DIR))
topics = pd.read_csv('{}/topics_translated.csv'.format(DATA_DIR))
documents = pd.read_csv('{}/documents.csv'.format(DATA_DIR))

# %% [markdown]
# # 1. Merge tables

# %%
def remove_users(events, transactions):
    tokens_event = set(events['transaction_token'].unique())
    print("{} tokens in events".format(len(tokens_event)))

    tokens_trans = set(transactions['transaction_token'].unique())
    print("{} tokens in transactions".format(len(tokens_trans)))

    missing_tokens = list(tokens_event - tokens_trans)
    missing_tokens.remove(np.nan)
    print("{} tokens in events but not in transactions".format(len(missing_tokens)))

    users_missing = list(events[events['transaction_token'].isin(missing_tokens)]['user_id'].unique())
    print("{} users in events but not in transactions".format(len(users_missing)))

    # Events without missing users. Equivalent to removing the missing tokens from events.
    len_events = len(events)
    events = events[~events['user_id'].isin(users_missing)]
    stat_events = (len_events - len(events))/len_events
    print("{}% of events eliminated".format(round(stat_events, 4)))

    return events, transactions

events, transactions = remove_users(events, transactions)
# Out:
# 637678 tokens in events
# 800018 tokens in transactions
# 37685 tokens in events but not in transactions
# 1304 users in events but not in transactions
# 0.0595% of events eliminated

# %%
df = pd.merge(events, users, on='user_id')
df = df.merge(transactions, on=['user_id', 'transaction_token'], how='left')
df = df.merge(sessions, on='transaction_id', how='left')
df['evaluation'] = df['evaluation'].map({"CORRECT": 1, "PARTIAL": 0.5, "WRONG": 0})
df = df.drop(['transaction_token', 'learn_session_id', 'max_num_tasks', 'user_agent'], axis=1)
df
# Out:
#          event_id  user_id      timestamp      category                action  \
# 0              69   392476  1621584325174          TASK         VIEW_QUESTION
# 1              70   392476  1621584365975          TASK         VIEW_QUESTION
# 2              72   392476  1621584441478          TASK         VIEW_QUESTION
# 3              73   392476  1621584446771          TASK          GO_TO_THEORY
# 4           54076   392476  1625054796765       GENERAL                 LOGIN
# ...           ...      ...            ...           ...                   ...
# 3259194   3516476   389181  1645514034678     DASHBOARD    NAVIGATE_DASHBOARD
# 3259195   3516528   389181  1645514507946  USER_SESSION  WINDOW_VISIBLE_FALSE
# 3259196   3516529   389181  1645514507951  USER_SESSION   WINDOW_VISIBLE_TRUE
# 3259197   3516530   389181  1645514523129  USER_SESSION  WINDOW_VISIBLE_FALSE
# 3259198   3516531   389181  1645514530255  USER_SESSION          WINDOW_CLOSE
#
#         event_type  session_id  \
# 0             VIEW     33768.0
# 1             VIEW     33768.0
# 2             VIEW     33768.0
# 3            CLICK     33768.0
# 4            CLICK         NaN
# ...            ...         ...
# 3259194       VIEW         NaN
# 3259195       VIEW         NaN
# 3259196       VIEW         NaN
# 3259197       VIEW         NaN
# 3259198       VIEW         NaN
#
#                                              tracking_data gender canton  ...  \
# 0                                                      NaN    NaN    NaN  ...
# 1                                                      NaN    NaN    NaN  ...
# 2                                                      NaN    NaN    NaN  ...
# 3                                                      NaN    NaN    NaN  ...
# 4                                                      NaN    NaN    NaN  ...
# ...                                                    ...    ...    ...  ...
# 3259194  {"dashboard": {"title": "Mathematik", "topics"...   MALE     SG  ...
# 3259195  {"location": "https://app.lernnavi.ch/dashboar...   MALE     SG  ...
# 3259196  {"location": "https://app.lernnavi.ch/dashboar...   MALE     SG  ...
# 3259197  {"location": "https://app.lernnavi.ch/dashboar...   MALE     SG  ...
# 3259198  {"location": "https://app.lernnavi.ch/dashboar...   MALE     SG  ...
#
#         input    start_time commit_time  validation  solution type  topic_id  \
# 0         NaN  1.620304e+12         NaN         NaN       NaN  NaN     951.0
# 1         NaN  1.620304e+12         NaN         NaN       NaN  NaN     951.0
# 2         NaN  1.620304e+12         NaN         NaN       NaN  NaN     951.0
# 3         NaN  1.620304e+12         NaN         NaN       NaN  NaN     951.0
# 4         NaN           NaN         NaN         NaN       NaN  NaN       NaN
# ...       ...           ...         ...         ...       ...  ...       ...
# 3259194   NaN           NaN         NaN         NaN       NaN  NaN       NaN
# 3259195   NaN           NaN         NaN         NaN       NaN  NaN       NaN
# 3259196   NaN           NaN         NaN         NaN       NaN  NaN       NaN
# 3259197   NaN           NaN         NaN         NaN       NaN  NaN       NaN
# 3259198   NaN           NaN         NaN         NaN       NaN  NaN       NaN
#
#          is_closed type_id is_accepted
# 0              0.0     1.0         NaN
# 1              0.0     1.0         NaN
# 2              0.0     1.0         NaN
# 3              0.0     1.0         NaN
# 4              NaN     NaN         NaN
# ...            ...     ...         ...
# 3259194        NaN     NaN         NaN
# 3259195        NaN     NaN         NaN
# 3259196        NaN     NaN         NaN
# 3259197        NaN     NaN         NaN
# 3259198        NaN     NaN         NaN
#
# [3259199 rows x 25 columns]

# %%
import json
def get_difficulty(doc):
    res = None
    doc = json.loads(doc)
    if doc.get('metaData') is not None:
        res = doc.get('metaData').get('estimatedDifficulty')
    return res

documents.drop_duplicates(['document_id'], keep='last', inplace=True)
documents['difficulty'] = documents['content'].apply(lambda x: get_difficulty(x))
df = df.merge(documents[['document_id', 'difficulty']], on='document_id', how='left')
df
# Out:
#          event_id  user_id      timestamp      category                action  \
# 0              69   392476  1621584325174          TASK         VIEW_QUESTION
# 1              70   392476  1621584365975          TASK         VIEW_QUESTION
# 2              72   392476  1621584441478          TASK         VIEW_QUESTION
# 3              73   392476  1621584446771          TASK          GO_TO_THEORY
# 4           54076   392476  1625054796765       GENERAL                 LOGIN
# ...           ...      ...            ...           ...                   ...
# 3259194   3516476   389181  1645514034678     DASHBOARD    NAVIGATE_DASHBOARD
# 3259195   3516528   389181  1645514507946  USER_SESSION  WINDOW_VISIBLE_FALSE
# 3259196   3516529   389181  1645514507951  USER_SESSION   WINDOW_VISIBLE_TRUE
# 3259197   3516530   389181  1645514523129  USER_SESSION  WINDOW_VISIBLE_FALSE
# 3259198   3516531   389181  1645514530255  USER_SESSION          WINDOW_CLOSE
#
#         event_type  session_id  \
# 0             VIEW     33768.0
# 1             VIEW     33768.0
# 2             VIEW     33768.0
# 3            CLICK     33768.0
# 4            CLICK         NaN
# ...            ...         ...
# 3259194       VIEW         NaN
# 3259195       VIEW         NaN
# 3259196       VIEW         NaN
# 3259197       VIEW         NaN
# 3259198       VIEW         NaN
#
#                                              tracking_data gender canton  ...  \
# 0                                                      NaN    NaN    NaN  ...
# 1                                                      NaN    NaN    NaN  ...
# 2                                                      NaN    NaN    NaN  ...
# 3                                                      NaN    NaN    NaN  ...
# 4                                                      NaN    NaN    NaN  ...
# ...                                                    ...    ...    ...  ...
# 3259194  {"dashboard": {"title": "Mathematik", "topics"...   MALE     SG  ...
# 3259195  {"location": "https://app.lernnavi.ch/dashboar...   MALE     SG  ...
# 3259196  {"location": "https://app.lernnavi.ch/dashboar...   MALE     SG  ...
# 3259197  {"location": "https://app.lernnavi.ch/dashboar...   MALE     SG  ...
# 3259198  {"location": "https://app.lernnavi.ch/dashboar...   MALE     SG  ...
#
#            start_time  commit_time validation  solution  type topic_id  \
# 0        1.620304e+12          NaN        NaN       NaN   NaN    951.0
# 1        1.620304e+12          NaN        NaN       NaN   NaN    951.0
# 2        1.620304e+12          NaN        NaN       NaN   NaN    951.0
# 3        1.620304e+12          NaN        NaN       NaN   NaN    951.0
# 4                 NaN          NaN        NaN       NaN   NaN      NaN
# ...               ...          ...        ...       ...   ...      ...
# 3259194           NaN          NaN        NaN       NaN   NaN      NaN
# 3259195           NaN          NaN        NaN       NaN   NaN      NaN
# 3259196           NaN          NaN        NaN       NaN   NaN      NaN
# 3259197           NaN          NaN        NaN       NaN   NaN      NaN
# 3259198           NaN          NaN        NaN       NaN   NaN      NaN
#
#          is_closed  type_id is_accepted difficulty
# 0              0.0      1.0         NaN        2.0
# 1              0.0      1.0         NaN        2.0
# 2              0.0      1.0         NaN        2.0
# 3              0.0      1.0         NaN        2.0
# 4              NaN      NaN         NaN        NaN
# ...            ...      ...         ...        ...
# 3259194        NaN      NaN         NaN        NaN
# 3259195        NaN      NaN         NaN        NaN
# 3259196        NaN      NaN         NaN        NaN
# 3259197        NaN      NaN         NaN        NaN
# 3259198        NaN      NaN         NaN        NaN
#
# [3259199 rows x 26 columns]

# %%
topics.rename(columns={'id': 'topic_id'}, inplace=True)
topics['german'] = abs(1 - topics['math'])
df = df.merge(topics[['topic_id', 'math', 'german']], on='topic_id', how='left')
df
# Out:
#          event_id  user_id      timestamp      category                action  \
# 0              69   392476  1621584325174          TASK         VIEW_QUESTION
# 1              70   392476  1621584365975          TASK         VIEW_QUESTION
# 2              72   392476  1621584441478          TASK         VIEW_QUESTION
# 3              73   392476  1621584446771          TASK          GO_TO_THEORY
# 4           54076   392476  1625054796765       GENERAL                 LOGIN
# ...           ...      ...            ...           ...                   ...
# 3259194   3516476   389181  1645514034678     DASHBOARD    NAVIGATE_DASHBOARD
# 3259195   3516528   389181  1645514507946  USER_SESSION  WINDOW_VISIBLE_FALSE
# 3259196   3516529   389181  1645514507951  USER_SESSION   WINDOW_VISIBLE_TRUE
# 3259197   3516530   389181  1645514523129  USER_SESSION  WINDOW_VISIBLE_FALSE
# 3259198   3516531   389181  1645514530255  USER_SESSION          WINDOW_CLOSE
#
#         event_type  session_id  \
# 0             VIEW     33768.0
# 1             VIEW     33768.0
# 2             VIEW     33768.0
# 3            CLICK     33768.0
# 4            CLICK         NaN
# ...            ...         ...
# 3259194       VIEW         NaN
# 3259195       VIEW         NaN
# 3259196       VIEW         NaN
# 3259197       VIEW         NaN
# 3259198       VIEW         NaN
#
#                                              tracking_data gender canton  ...  \
# 0                                                      NaN    NaN    NaN  ...
# 1                                                      NaN    NaN    NaN  ...
# 2                                                      NaN    NaN    NaN  ...
# 3                                                      NaN    NaN    NaN  ...
# 4                                                      NaN    NaN    NaN  ...
# ...                                                    ...    ...    ...  ...
# 3259194  {"dashboard": {"title": "Mathematik", "topics"...   MALE     SG  ...
# 3259195  {"location": "https://app.lernnavi.ch/dashboar...   MALE     SG  ...
# 3259196  {"location": "https://app.lernnavi.ch/dashboar...   MALE     SG  ...
# 3259197  {"location": "https://app.lernnavi.ch/dashboar...   MALE     SG  ...
# 3259198  {"location": "https://app.lernnavi.ch/dashboar...   MALE     SG  ...
#
#         validation  solution type  topic_id  is_closed type_id  is_accepted  \
# 0              NaN       NaN  NaN     951.0        0.0     1.0          NaN
# 1              NaN       NaN  NaN     951.0        0.0     1.0          NaN
# 2              NaN       NaN  NaN     951.0        0.0     1.0          NaN
# 3              NaN       NaN  NaN     951.0        0.0     1.0          NaN
# 4              NaN       NaN  NaN       NaN        NaN     NaN          NaN
# ...            ...       ...  ...       ...        ...     ...          ...
# 3259194        NaN       NaN  NaN       NaN        NaN     NaN          NaN
# 3259195        NaN       NaN  NaN       NaN        NaN     NaN          NaN
# 3259196        NaN       NaN  NaN       NaN        NaN     NaN          NaN
# 3259197        NaN       NaN  NaN       NaN        NaN     NaN          NaN
# 3259198        NaN       NaN  NaN       NaN        NaN     NaN          NaN
#
#          difficulty math german
# 0               2.0  1.0    0.0
# 1               2.0  1.0    0.0
# 2               2.0  1.0    0.0
# 3               2.0  1.0    0.0
# 4               NaN  NaN    NaN
# ...             ...  ...    ...
# 3259194         NaN  NaN    NaN
# 3259195         NaN  NaN    NaN
# 3259196         NaN  NaN    NaN
# 3259197         NaN  NaN    NaN
# 3259198         NaN  NaN    NaN
#
# [3259199 rows x 28 columns]

# %% [markdown]
# # 2.preprocess

# %%
df['date'] = pd.to_datetime(df['timestamp'], unit='ms').dt.date  # convert timestamp to pd.datetime
users_day_event = df.groupby(['user_id', 'date'])  # groupby users' daily

# number of questions user answers in a day
user_num_questions = users_day_event.apply(lambda x: len(x[x['action'] == 'SUBMIT_ANSWER']))
user_num_questions = user_num_questions.reset_index(name='num_questions')

user_stats = pd.merge(users, user_num_questions, on='user_id')
user_stats
# Out:
#        user_id  gender canton                  class_level        date  \
# 0       387604     NaN    NaN                          NaN  2021-05-22
# 1       387604     NaN    NaN                          NaN  2021-05-28
# 2       387604     NaN    NaN                          NaN  2021-06-23
# 3       387604     NaN    NaN                          NaN  2021-07-02
# 4       387604     NaN    NaN                          NaN  2021-08-06
# ...        ...     ...    ...                          ...         ...
# 38048   404599     NaN    NaN                          NaN  2022-02-21
# 38049   404603  FEMALE     SO          Gymnasium - 4. Jahr  2022-02-21
# 38050   404604  FEMALE     ZH  Langzeitgymnasium - 2. Jahr  2022-02-21
# 38051   404605  FEMALE     SO          Gymnasium - 3. Jahr  2022-02-21
# 38052   404623    MALE     BL          Gymnasium - 1. Jahr  2022-02-21
#
#        num_questions
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 38048              1
# 38049             13
# 38050              4
# 38051              0
# 38052              0
#
# [38053 rows x 6 columns]

# %%
# number of users' action in a day
user_stats = user_stats.merge(users_day_event.apply(len).reset_index(name='num_events'), on=['user_id', 'date'])
user_stats
# Out:
#        user_id  gender canton                  class_level        date  \
# 0       387604     NaN    NaN                          NaN  2021-05-22
# 1       387604     NaN    NaN                          NaN  2021-05-28
# 2       387604     NaN    NaN                          NaN  2021-06-23
# 3       387604     NaN    NaN                          NaN  2021-07-02
# 4       387604     NaN    NaN                          NaN  2021-08-06
# ...        ...     ...    ...                          ...         ...
# 38048   404599     NaN    NaN                          NaN  2022-02-21
# 38049   404603  FEMALE     SO          Gymnasium - 4. Jahr  2022-02-21
# 38050   404604  FEMALE     ZH  Langzeitgymnasium - 2. Jahr  2022-02-21
# 38051   404605  FEMALE     SO          Gymnasium - 3. Jahr  2022-02-21
# 38052   404623    MALE     BL          Gymnasium - 1. Jahr  2022-02-21
#
#        num_questions  num_events
# 0                  0           1
# 1                  0           1
# 2                  0           7
# 3                  0          25
# 4                  0          12
# ...              ...         ...
# 38048              1         169
# 38049             13         112
# 38050              4          43
# 38051              0          22
# 38052              0          37
#
# [38053 rows x 7 columns]

# %%
# the percentage of correct answers in a day
percentage_correct = users_day_event.apply(lambda x: x['evaluation'].sum() / len(x[x['evaluation'] != np.nan]))
user_stats = user_stats.merge(percentage_correct.reset_index(name='percentage_correct'), on=['user_id', 'date'])
user_stats
# Out:
#        user_id gender canton          class_level        date  num_questions  \
# 0       387604    NaN    NaN                  NaN  2021-05-22              0
# 1       387604    NaN    NaN                  NaN  2021-05-28              0
# 2       387604    NaN    NaN                  NaN  2021-06-23              0
# 3       387604    NaN    NaN                  NaN  2021-07-02              0
# 4       387604    NaN    NaN                  NaN  2021-08-06              0
# ...        ...    ...    ...                  ...         ...            ...
# 38511   404564   MALE     SO  Gymnasium - 2. Jahr  2022-02-22              0
# 38512   404565   MALE     SO  Gymnasium - 2. Jahr  2022-02-21              0
# 38513   404565   MALE     SO  Gymnasium - 2. Jahr  2022-02-22              3
# 38514   404598   MALE     SG  Gymnasium - 1. Jahr  2022-02-21              1
# 38515   404598   MALE     SG  Gymnasium - 1. Jahr  2022-02-22              0
#
#        num_events  percentage_correct
# 0               1            0.000000
# 1               1            0.000000
# 2               7            0.000000
# 3              25            0.000000
# 4              12            0.000000
# ...           ...                 ...
# 38511          28            0.000000
# 38512           9            0.000000
# 38513          70            0.085714
# 38514         220            0.013636
# 38515           5            0.000000
#
# [38516 rows x 8 columns]

# %%
duration = pd.to_timedelta(pd.to_datetime(users_day_event['timestamp'].max(), unit='ms')
                           - pd.to_datetime(users_day_event['timestamp'].min(), unit='ms')).dt.total_seconds() / 60
print(duration)
# Out:
# user_id  date
# 387604   2021-05-22      0.000000
#          2021-05-28      0.000000
#          2021-06-23      0.685000
#          2021-07-02     93.828200
#          2021-08-06      1.367617
#                           ...
# 404600   2022-02-21     34.882900
# 404603   2022-02-21    311.390483
# 404604   2022-02-21    107.607033
# 404605   2022-02-21     45.804750
# 404623   2022-02-21      9.882383
# Name: timestamp, Length: 41654, dtype: float64

# %%
user_stats = user_stats.groupby(['user_id']).filter(lambda x: len(x) > 1)  # filter out users only activate in one day
user_stats
# Out:
#        user_id gender canton          class_level        date  num_questions  \
# 0       387604    NaN    NaN                  NaN  2021-05-22              0
# 1       387604    NaN    NaN                  NaN  2021-05-28              0
# 2       387604    NaN    NaN                  NaN  2021-06-23              0
# 3       387604    NaN    NaN                  NaN  2021-07-02              0
# 4       387604    NaN    NaN                  NaN  2021-08-06              0
# ...        ...    ...    ...                  ...         ...            ...
# 38025   404564   MALE     SO  Gymnasium - 2. Jahr  2022-02-22              0
# 38026   404565   MALE     SO  Gymnasium - 2. Jahr  2022-02-21              0
# 38027   404565   MALE     SO  Gymnasium - 2. Jahr  2022-02-22              3
# 38046   404598   MALE     SG  Gymnasium - 1. Jahr  2022-02-21              1
# 38047   404598   MALE     SG  Gymnasium - 1. Jahr  2022-02-22              0
#
#        num_events
# 0               1
# 1               1
# 2               7
# 3              25
# 4              12
# ...           ...
# 38025          28
# 38026           9
# 38027          70
# 38046         220
# 38047           5
#
# [35394 rows x 7 columns]

# %%
session_length = users_day_event['session_id'].count()
print(session_length)
# Out:
# user_id  date
# 387604   2021-05-22     0
#          2021-05-28     0
#          2021-06-23     3
#          2021-07-02    17
#          2021-08-06     0
#                        ..
# 404600   2022-02-21     0
# 404603   2022-02-21    65
# 404604   2022-02-21    25
# 404605   2022-02-21     0
# 404623   2022-02-21     0
# Name: session_id, Length: 41654, dtype: int64

# %%
users_day_event = users_day_event.merge(users, on='user_id', how='left')
users_day_event
# Out:
#        user_id        date  num_events  gender canton  \
# 0       387604  2021-05-22           1     NaN    NaN
# 1       387604  2021-05-28           1     NaN    NaN
# 2       387604  2021-06-23           7     NaN    NaN
# 3       387604  2021-07-02          25     NaN    NaN
# 4       387604  2021-08-06          12     NaN    NaN
# ...        ...         ...         ...     ...    ...
# 38048   404599  2022-02-21         169     NaN    NaN
# 38049   404603  2022-02-21         112  FEMALE     SO
# 38050   404604  2022-02-21          43  FEMALE     ZH
# 38051   404605  2022-02-21          22  FEMALE     SO
# 38052   404623  2022-02-21          37    MALE     BL
#
#                        class_level
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 38048                          NaN
# 38049          Gymnasium - 4. Jahr
# 38050  Langzeitgymnasium - 2. Jahr
# 38051          Gymnasium - 3. Jahr
# 38052          Gymnasium - 1. Jahr
#
# [38053 rows x 6 columns]

# %%
# Out:
#        user_id        date  num_events gender canton          class_level
# 0       387604  2021-05-22           1    NaN    NaN                  NaN
# 1       387604  2021-05-28           1    NaN    NaN                  NaN
# 2       387604  2021-06-23           7    NaN    NaN                  NaN
# 3       387604  2021-07-02          25    NaN    NaN                  NaN
# 4       387604  2021-08-06          12    NaN    NaN                  NaN
# ...        ...         ...         ...    ...    ...                  ...
# 38025   404564  2022-02-22          28   MALE     SO  Gymnasium - 2. Jahr
# 38026   404565  2022-02-21           9   MALE     SO  Gymnasium - 2. Jahr
# 38027   404565  2022-02-22          70   MALE     SO  Gymnasium - 2. Jahr
# 38046   404598  2022-02-21         220   MALE     SG  Gymnasium - 1. Jahr
# 38047   404598  2022-02-22           5   MALE     SG  Gymnasium - 1. Jahr
#
# [35394 rows x 6 columns]

# %%
from datetime import timedelta
user_stats['date'].quantile(0.8) + timedelta(days=7)
# Out:
# datetime.date(2022, 1, 26)

# %%
user_stats['date_shift'] = user_stats.groupby(['user_id'])['date'].shift(-1)
user_stats_labeled = user_stats.dropna(subset=['date_shift'])
user_stats_labeled['label'] = user_stats['date'] + timedelta(days=7) >= user_stats['date_shift']
user_stats_labeled
# Out:
#        user_id  gender canton          class_level        date  num_questions  \
# 0       387604     NaN    NaN                  NaN  2021-05-22              0
# 1       387604     NaN    NaN                  NaN  2021-05-28              0
# 2       387604     NaN    NaN                  NaN  2021-06-23              0
# 3       387604     NaN    NaN                  NaN  2021-07-02              0
# 4       387604     NaN    NaN                  NaN  2021-08-06              0
# ...        ...     ...    ...                  ...         ...            ...
# 38020   404561  FEMALE     SO  Gymnasium - 2. Jahr  2022-02-21              1
# 38022   404563  FEMALE     SO  Gymnasium - 2. Jahr  2022-02-21              0
# 38024   404564    MALE     SO  Gymnasium - 2. Jahr  2022-02-21              1
# 38026   404565    MALE     SO  Gymnasium - 2. Jahr  2022-02-21              0
# 38046   404598    MALE     SG  Gymnasium - 1. Jahr  2022-02-21              1
#
#        num_events  date_shift  label
# 0               1  2021-05-28   True
# 1               1  2021-06-23  False
# 2               7  2021-07-02  False
# 3              25  2021-08-06  False
# 4              12  2021-08-13   True
# ...           ...         ...    ...
# 38020          48  2022-02-22   True
# 38022          69  2022-02-22   True
# 38024          32  2022-02-22   True
# 38026           9  2022-02-22   True
# 38046         220  2022-02-22   True
#
# [29244 rows x 9 columns]

# %%
group_stats = user_stats_labeled.groupby('user_id')
len(group_stats)
# Out:
# 6150

# %%
from collections import defaultdict
dates = sorted(user_stats_labeled['date'].unique())

datas = defaultdict(list)
gp_sub = []
num_data = 0
for date in dates:
    print(date)
    sub_data = user_stats_labeled[user_stats_labeled['date'] == date]
    sub_data = user_stats_labeled[user_stats_labeled['user_id'].apply(lambda x: x in sub_data['user_id'].values)]
    sub_data = sub_data[sub_data['date'] <= date]
    group_sub_data = sub_data.groupby('user_id')
    for window_size in range(1, group_sub_data.apply(len).max()+1):
        group_sub_data = group_sub_data.filter(lambda x: len(x) >= window_size).groupby('user_id')
        num_data += len(group_sub_data)
        slice_data = group_sub_data.tail(window_size).reset_index(drop=True)
        datas[window_size].append(slice_data)

    # tmp = sub_data.drop_duplicates('user_id', keep='last')
    # tmp['activity_day'] = sub_data.groupby('user_id').apply(len).values
    # gp_sub.append(sub_data.groupby('user_id').apply(len))
    # datas.append(tmp)
# Out:
# 2021-05-21
# 2021-05-22
# 2021-05-23
# 2021-05-24
# 2021-05-25
# 2021-05-26
# 2021-05-27
# 2021-05-28
# 2021-05-29
# 2021-05-30
# 2021-05-31
# 2021-06-01
# 2021-06-02
# 2021-06-03
# 2021-06-04
# 2021-06-05
# 2021-06-06
# 2021-06-07
# 2021-06-08
# 2021-06-09
# 2021-06-10
# 2021-06-11
# 2021-06-12
# 2021-06-13
# 2021-06-14
# 2021-06-15
# 2021-06-16
# 2021-06-17
# 2021-06-18
# 2021-06-19
# 2021-06-20
# 2021-06-21
# 2021-06-22
# 2021-06-23
# 2021-06-24
# 2021-06-25
# 2021-06-26
# 2021-06-27
# 2021-06-28
# 2021-06-29
# 2021-06-30
# 2021-07-01
# 2021-07-02
# 2021-07-03
# 2021-07-04
# 2021-07-05
# 2021-07-06
# 2021-07-07
# 2021-07-08
# 2021-07-09
# 2021-07-10
# 2021-07-11
# 2021-07-12
# 2021-07-13
# 2021-07-14
# 2021-07-15
# 2021-07-16
# 2021-07-17
# 2021-07-18
# 2021-07-19
# 2021-07-20
# 2021-07-21
# 2021-07-22
# 2021-07-23
# 2021-07-24
# 2021-07-25
# 2021-07-26
# 2021-07-27
# 2021-07-28
# 2021-07-29
# 2021-07-30
# 2021-07-31
# 2021-08-01
# 2021-08-03
# 2021-08-04
# 2021-08-05
# 2021-08-06
# 2021-08-07
# 2021-08-08
# 2021-08-09
# 2021-08-10
# 2021-08-11
# 2021-08-12
# 2021-08-13
# 2021-08-14
# 2021-08-15
# 2021-08-16
# 2021-08-17
# 2021-08-18
# 2021-08-19
# 2021-08-20
# 2021-08-21
# 2021-08-22
# 2021-08-23
# 2021-08-24
# 2021-08-25
# 2021-08-26
# 2021-08-27
# 2021-08-28
# 2021-08-29
# 2021-08-30
# 2021-08-31
# 2021-09-01
# 2021-09-02
# 2021-09-03
# 2021-09-04
# 2021-09-05
# 2021-09-06
# 2021-09-07
# 2021-09-08
# 2021-09-09
# 2021-09-10
# 2021-09-11
# 2021-09-12
# 2021-09-13
# 2021-09-14
# 2021-09-15
# 2021-09-16
# 2021-09-17
# 2021-09-18
# 2021-09-19
# 2021-09-20
# 2021-09-21
# 2021-09-22
# 2021-09-23
# 2021-09-24
# 2021-09-25
# 2021-09-26
# 2021-09-27
# 2021-09-28
# 2021-09-29
# 2021-09-30
# 2021-10-01
# 2021-10-02
# 2021-10-03
# 2021-10-04
# 2021-10-05
# 2021-10-06
# 2021-10-07
# 2021-10-08
# 2021-10-09
# 2021-10-10
# 2021-10-11
# 2021-10-12
# 2021-10-13
# 2021-10-14
# 2021-10-15
# 2021-10-16
# 2021-10-17
# 2021-10-18
# 2021-10-19
# 2021-10-20
# 2021-10-21
# 2021-10-22
# 2021-10-23
# 2021-10-24
# 2021-10-25
# 2021-10-26
# 2021-10-27
# 2021-10-28
# 2021-10-29
# 2021-10-30
# 2021-10-31
# 2021-11-01
# 2021-11-02
# 2021-11-03
# 2021-11-04
# 2021-11-05
# 2021-11-06
# 2021-11-07
# 2021-11-08
# 2021-11-09
# 2021-11-10
# 2021-11-11
# 2021-11-12
# 2021-11-13
# 2021-11-14
# 2021-11-15
# 2021-11-16
# 2021-11-17
# 2021-11-18
# 2021-11-19
# 2021-11-20
# 2021-11-21
# 2021-11-22
# 2021-11-23
# 2021-11-24
# 2021-11-25
# 2021-11-26
# 2021-11-27
# 2021-11-28
# 2021-11-29
# 2021-11-30
# 2021-12-01
# 2021-12-02
# 2021-12-03
# 2021-12-04
# 2021-12-05
# 2021-12-06
# 2021-12-07
# 2021-12-08
# 2021-12-09
# 2021-12-10
# 2021-12-11
# 2021-12-12
# 2021-12-13
# 2021-12-14
# 2021-12-15
# 2021-12-16
# 2021-12-17
# 2021-12-18
# 2021-12-19
# 2021-12-20
# 2021-12-21
# 2021-12-22
# 2021-12-23
# 2021-12-24
# 2021-12-25
# 2021-12-26
# 2021-12-27
# 2021-12-28
# 2021-12-29
# 2021-12-30
# 2021-12-31
# 2022-01-01
# 2022-01-02
# 2022-01-03
# 2022-01-04
# 2022-01-05
# 2022-01-06
# 2022-01-07
# 2022-01-08
# 2022-01-09
# 2022-01-10
# 2022-01-11
# 2022-01-12
# 2022-01-13
# 2022-01-14
# 2022-01-15
# 2022-01-16
# 2022-01-17
# 2022-01-18
# 2022-01-19
# 2022-01-20
# 2022-01-21
# 2022-01-22
# 2022-01-23
# 2022-01-24
# 2022-01-25
# 2022-01-26
# 2022-01-27
# 2022-01-28
# 2022-01-29
# 2022-01-30
# 2022-01-31
# 2022-02-01
# 2022-02-02
# 2022-02-03
# 2022-02-04
# 2022-02-05
# 2022-02-06
# 2022-02-07
# 2022-02-08
# 2022-02-09
# 2022-02-10
# 2022-02-11
# 2022-02-12
# 2022-02-13
# 2022-02-14
# 2022-02-15
# 2022-02-16
# 2022-02-17
# 2022-02-18
# 2022-02-19
# 2022-02-20
# 2022-02-21

# %%
# datas[2][1]
num_data
# Out:
# 207821

# %%
num = 0
for x in datas.values():
    num+=len(x)
num
# Out:
# 12478

# %%
date = pd.to_datetime('2021-08-02')
sub_data = user_stats_labeled[user_stats_labeled['date'] ==date]
sub_data = user_stats_labeled[user_stats_labeled['user_id'].apply(lambda x: x in sub_data['user_id'].values)]
sub_data = sub_data[sub_data['date'] <= date]
group_sub_data = sub_data.groupby('user_id')
# sub_data
user_stats_labeled[user_stats_labeled['date'] ==date]
# Out:
# Empty DataFrame
# Columns: [user_id, gender, canton, class_level, date, num_questions, num_events, date_shift, label]
# Index: []

# %%
# Out:
# Timestamp('2021-08-02 00:00:00')

# %%
users_day_event_labeled[users_day_event_labeled['user_id'] == 393262]
# Out:
#       user_id        date  num_events  gender canton    class_level  \
# 5841   393262  2021-05-26          19  FEMALE     SG  FMS - 2. Jahr
# 5842   393262  2021-05-28          10  FEMALE     SG  FMS - 2. Jahr
# 5843   393262  2021-05-30           1  FEMALE     SG  FMS - 2. Jahr
# 5844   393262  2021-05-31           6  FEMALE     SG  FMS - 2. Jahr
# 5845   393262  2022-01-03          32  FEMALE     SG  FMS - 2. Jahr
# 5846   393262  2022-01-07          77  FEMALE     SG  FMS - 2. Jahr
# 5847   393262  2022-01-14          38  FEMALE     SG  FMS - 2. Jahr
# 5848   393262  2022-01-28          45  FEMALE     SG  FMS - 2. Jahr
# 5849   393262  2022-02-17          15  FEMALE     SG  FMS - 2. Jahr
#
#       date_shift  label
# 5841  2021-05-28   True
# 5842  2021-05-30   True
# 5843  2021-05-31   True
# 5844  2022-01-03  False
# 5845  2022-01-07   True
# 5846  2022-01-14   True
# 5847  2022-01-28  False
# 5848  2022-02-17  False
# 5849  2022-02-18   True

# %%
topics.rename(columns={'id': 'topic_id'}, inplace=True)
# Out:
#           event_id  user_id      timestamp category         action event_type  \
# 0               69   392476  1621584325174     TASK  VIEW_QUESTION       VIEW
# 1               69   392476  1621584325174     TASK  VIEW_QUESTION       VIEW
# 2               69   392476  1621584325174     TASK  VIEW_QUESTION       VIEW
# 3               69   392476  1621584325174     TASK  VIEW_QUESTION       VIEW
# 4               69   392476  1621584325174     TASK  VIEW_QUESTION       VIEW
# ...            ...      ...            ...      ...            ...        ...
# 13095968   3516474   389181  1645514034057  SESSION          CLOSE      CLICK
# 13095969   3516474   389181  1645514034057  SESSION          CLOSE      CLICK
# 13095970   3516474   389181  1645514034057  SESSION          CLOSE      CLICK
# 13095971   3516474   389181  1645514034057  SESSION          CLOSE      CLICK
# 13095972   3516474   389181  1645514034057  SESSION          CLOSE      CLICK
#
#           session_id tracking_data gender canton  ... topic_id  is_closed  \
# 0            33768.0           NaN    NaN    NaN  ...    951.0        0.0
# 1            33768.0           NaN    NaN    NaN  ...    951.0        0.0
# 2            33768.0           NaN    NaN    NaN  ...    951.0        0.0
# 3            33768.0           NaN    NaN    NaN  ...    951.0        0.0
# 4            33768.0           NaN    NaN    NaN  ...    951.0        0.0
# ...              ...           ...    ...    ...  ...      ...        ...
# 13095968    112223.0           NaN   MALE     SG  ...      NaN        NaN
# 13095969    112223.0           NaN   MALE     SG  ...      NaN        NaN
# 13095970    112223.0           NaN   MALE     SG  ...      NaN        NaN
# 13095971    112223.0           NaN   MALE     SG  ...      NaN        NaN
# 13095972    112223.0           NaN   MALE     SG  ...      NaN        NaN
#
#          type_id  is_accepted difficulty          name  \
# 0            1.0          NaN        NaN  Zahlenmengen
# 1            1.0          NaN        NaN  Zahlenmengen
# 2            1.0          NaN        NaN  Zahlenmengen
# 3            1.0          NaN        1.0  Zahlenmengen
# 4            1.0          NaN        1.0  Zahlenmengen
# ...          ...          ...        ...           ...
# 13095968     NaN          NaN        1.0           NaN
# 13095969     NaN          NaN        1.0           NaN
# 13095970     NaN          NaN        1.0           NaN
# 13095971     NaN          NaN        1.0           NaN
# 13095972     NaN          NaN        1.0           NaN
#
#                                                 description  name_english  \
# 0         Die Schülerinnen und Schüler kennen die Zahlen...    Quantities
# 1         Die Schülerinnen und Schüler kennen die Zahlen...    Quantities
# 2         Die Schülerinnen und Schüler kennen die Zahlen...    Quantities
# 3         Die Schülerinnen und Schüler kennen die Zahlen...    Quantities
# 4         Die Schülerinnen und Schüler kennen die Zahlen...    Quantities
# ...                                                     ...           ...
# 13095968                                                NaN           NaN
# 13095969                                                NaN           NaN
# 13095970                                                NaN           NaN
# 13095971                                                NaN           NaN
# 13095972                                                NaN           NaN
#
#                                         description_english math
# 0         The students know the number of numbers and th...  1.0
# 1         The students know the number of numbers and th...  1.0
# 2         The students know the number of numbers and th...  1.0
# 3         The students know the number of numbers and th...  1.0
# 4         The students know the number of numbers and th...  1.0
# ...                                                     ...  ...
# 13095968                                                NaN  NaN
# 13095969                                                NaN  NaN
# 13095970                                                NaN  NaN
# 13095971                                                NaN  NaN
# 13095972                                                NaN  NaN
#
# [13095973 rows x 31 columns]

# %%
df2 = df2.merge(topics[['topic_id', 'math']], on='topic_id', how='left')
df2
# Out:
#          event_id  user_id      timestamp  category          action  \
# 0              69   392476  1621584325174      TASK   VIEW_QUESTION
# 1              70   392476  1621584365975      TASK   VIEW_QUESTION
# 2              72   392476  1621584441478      TASK   VIEW_QUESTION
# 3              73   392476  1621584446771      TASK    GO_TO_THEORY
# 4             223   393213  1621589245107      TASK   VIEW_QUESTION
# ...           ...      ...            ...       ...             ...
# 1506881   3516466   389181  1645514014647  FEEDBACK   OPEN_FEEDBACK
# 1506882   3516467   389181  1645514016163  FEEDBACK  CLOSE_FEEDBACK
# 1506883   3516468   389181  1645514024160      TASK            NEXT
# 1506884   3516473   389181  1645514033264      TASK   VIEW_QUESTION
# 1506885   3516474   389181  1645514034057   SESSION           CLOSE
#
#         event_type  session_id  \
# 0             VIEW     33768.0
# 1             VIEW     33768.0
# 2             VIEW     33768.0
# 3            CLICK     33768.0
# 4             VIEW     34343.0
# ...            ...         ...
# 1506881      CLICK    112223.0
# 1506882      CLICK    112223.0
# 1506883      CLICK    112223.0
# 1506884       VIEW    112223.0
# 1506885      CLICK    112223.0
#
#                                              tracking_data gender canton  ...  \
# 0                                                      NaN    NaN    NaN  ...
# 1                                                      NaN    NaN    NaN  ...
# 2                                                      NaN    NaN    NaN  ...
# 3                                                      NaN    NaN    NaN  ...
# 4                                                      NaN    NaN    NaN  ...
# ...                                                    ...    ...    ...  ...
# 1506881  {"popoverId": "e6b42e8e-542e-4ba0-a6c0-dc5f498...   MALE     SG  ...
# 1506882  {"popoverId": "e6b42e8e-542e-4ba0-a6c0-dc5f498...   MALE     SG  ...
# 1506883                                                NaN   MALE     SG  ...
# 1506884                                                NaN   MALE     SG  ...
# 1506885                                                NaN   MALE     SG  ...
#
#           commit_time  validation  \
# 0                 NaN         NaN
# 1                 NaN         NaN
# 2                 NaN         NaN
# 3                 NaN         NaN
# 4                 NaN         NaN
# ...               ...         ...
# 1506881  1.645514e+12        PASS
# 1506882  1.645514e+12        PASS
# 1506883  1.645514e+12        PASS
# 1506884           NaN         NaN
# 1506885           NaN         NaN
#
#                                                   solution  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1506881  {"gaps": ["Richtig", "Nicht notwendig", "Richt...
# 1506882  {"gaps": ["Richtig", "Nicht notwendig", "Richt...
# 1506883  {"gaps": ["Richtig", "Nicht notwendig", "Richt...
# 1506884                                                NaN
# 1506885                                                NaN
#
#                         type topic_id is_closed  type_id  is_accepted  \
# 0                        NaN    951.0       0.0      1.0          NaN
# 1                        NaN    951.0       0.0      1.0          NaN
# 2                        NaN    951.0       0.0      1.0          NaN
# 3                        NaN    951.0       0.0      1.0          NaN
# 4                        NaN    952.0       0.0      1.0          NaN
# ...                      ...      ...       ...      ...          ...
# 1506881  CLOZE_TEXT_DROPDOWN    978.0       1.0      1.0          1.0
# 1506882  CLOZE_TEXT_DROPDOWN    978.0       1.0      1.0          1.0
# 1506883  CLOZE_TEXT_DROPDOWN    978.0       1.0      1.0          1.0
# 1506884                  NaN      NaN       NaN      NaN          NaN
# 1506885                  NaN      NaN       NaN      NaN          NaN
#
#         difficulty math
# 0              2.0  1.0
# 1              2.0  1.0
# 2              2.0  1.0
# 3              2.0  1.0
# 4              2.0  1.0
# ...            ...  ...
# 1506881        1.0  1.0
# 1506882        1.0  1.0
# 1506883        1.0  1.0
# 1506884        1.0  NaN
# 1506885        1.0  NaN
#
# [1506886 rows x 27 columns]

# %%
df_group = df2.groupby('user_id')

# %%
def count_navi_num(x):
    if 'NAVIGATE_DASHBOARD' in x['action'].values:
        return x['action'].value_counts()['NAVIGATE_DASHBOARD']
    else:
        return 0
df_group.apply(count_navi_num).sort_values(ascending=False)
# Out:
# user_id
# 396334    971
# 393686    864
# 394739    847
# 394987    841
# 393959    821
#          ...
# 400727      0
# 403229      0
# 403230      0
# 400715      0
# 400180      0
# Length: 10113, dtype: int64

# %%
def count_level_check_num(x):
    x = x.drop_duplicates('session_id')
    return len(x[x['type_id'] == 2])
df_group.apply(count_level_check_num).sort_values(ascending=False)
# Out:
# user_id
# 396341    79
# 401331    61
# 393959    58
# 394171    52
# 396334    52
#           ..
# 398567     0
# 398566     0
# 398565     0
# 398564     0
# 404623     0
# Length: 10113, dtype: int64

# %%
df2['action'].value_counts()['NAVIGATE_DASHBOARD']
# Out:
# 350821

# %%
'NAVIGATE_DASHBOARD' in df2['action']
# Out:
# False

# %%
df2['action']
# Out:
# 0                 VIEW_QUESTION
# 1                 SUBMIT_ANSWER
# 2                          NEXT
# 3                 VIEW_QUESTION
# 4                 SUBMIT_ANSWER
#                    ...
# 3465554      NAVIGATE_DASHBOARD
# 3465555    WINDOW_VISIBLE_FALSE
# 3465556     WINDOW_VISIBLE_TRUE
# 3465557    WINDOW_VISIBLE_FALSE
# 3465558            WINDOW_CLOSE
# Name: action, Length: 3465559, dtype: object
